# %%
import os
from google.colab import drive

drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/Projetos/Funcoes

import time
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/Projetos/Funcoes

# %%
import funcoes
# Out:
# import chime
# No module named 'chime'
# chime installed successfully
# import chime

# %%
funcoes.read_and_create_feather('files/nubank-2022-02.csv')
funcoes.success()

# %%
funcoes.try_import('chime')
funcoes.try_import('gspread_formatting','*')
# Out:
# import chime
